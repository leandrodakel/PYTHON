# %% [markdown]
# <a href="https://colab.research.google.com/github/leandrodakel/PYTHON/blob/main/graficos_estatisticos_seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Criando gráficos estatísticos usando seaborn

import seaborn as sns

import matplotlib.pyplot as plt



sns.set(style="whitegrid") # opções: darkgrid, whitegrid, dark, white, ticks



df_tips = sns.load_dataset('tips')



fig, ax = plt.subplots(1, 3, figsize=(15, 5))


# Calculando a média
sns.barplot(data=df_tips, x='sex', y='total_bill', ax=ax[0])


sns.barplot(data=df_tips, x='sex', y='total_bill', ax=ax[1], estimator=sum)

sns.barplot(data=df_tips, x='sex', y='total_bill', ax=ax[2], estimator=len)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>
